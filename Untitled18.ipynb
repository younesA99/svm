# %% [markdown]
# <a href="https://colab.research.google.com/github/younesA99/svm/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
#load the data
dataset=pd.read_excel("Concrete_Data.xls")
dataset.head()
#renaming all featurses
dataset.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']
dataset.head()
x = dataset.drop('strength', axis=1)  # Features (independent variables)
y = dataset['strength']  # Target variable (dependent variable)
# Divisez les données en ensembles de formation et de test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Normalisation des données
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
fixed_params = {
    'hidden_layer_sizes': 132,
    'activation': 'relu',
    'solver': 'lbfgs',
    'max_iter': 5000,
    'alpha': 0.1
}
# Définir le modèle de régression MLP (Multi-layer Perceptron)
model = MLPRegressor(**fixed_params,random_state=42)

# Entraîner le modèle
model.fit(x_train_scaled, y_train)

# Faire des prédictions sur l'ensemble de test
y_pred_test = model.predict(x_test_scaled)

# Calculez les métriques de performance
mae_test = mean_absolute_error(y_test, y_pred_test)
rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)
r2_test = r2_score(y_test, y_pred_test)

# Faites des prédictions sur l'ensemble d'entraînement normalisé
y_pred_train = model.predict(x_train_scaled)

# Calculez les métriques de performance sur l'ensemble d'entraînement
mae_train = mean_absolute_error(y_train, y_pred_train)
rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
r2_train = r2_score(y_train, y_pred_train)

print("Performance sur l'ensemble de test:")
print("Mean Absolute Error (MAE):", mae_test)
print("Root Mean Squared Error (RMSE):", rmse_test)
print("R-squared (R²):", r2_test)

print("\nPerformance sur l'ensemble d'entraînement:")
print("Mean Absolute Error (MAE):", mae_train)
print("Root Mean Squared Error (RMSE):", rmse_train)
print("R-squared (R²):", r2_train)





# Plot pour l'ensemble d'entraînement
plt.figure(figsize=(10, 5))
plt.scatter(y_train, y_pred_train, color='blue', label='Entraînement')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2, label='X=Y')
plt.xlabel('Valeurs Réelles')
plt.ylabel('Valeurs Prédites')
plt.title("Performance du Modèle - Ensemble d'Entraînement")
plt.legend()
plt.grid(True)
plt.show()

# Plot pour l'ensemble de test
plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_pred_test, color='green', label='Test')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2, label='X=Y')
plt.xlabel('Valeurs Réelles')
plt.ylabel('Valeurs Prédites')
plt.title("Performance du Modèle - Ensemble de Test")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Performance sur l'ensemble de test:
# Mean Absolute Error (MAE): 3.2650036287458604
# Root Mean Squared Error (RMSE): 4.9003933881008175
# R-squared (R²): 0.9068078471113867
#
# Performance sur l'ensemble d'entraînement:
# Mean Absolute Error (MAE): 0.7807376914396574
# Root Mean Squared Error (RMSE): 1.4617408889984433
# R-squared (R²): 0.9924786472860471

# %%
import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement
plt.figure(figsize=(10, 5))
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2, label='X=Y')
plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("Model Performance - Training Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)
plt.show()

# Plot pour l'ensemble de test
plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_pred_test, color='green', label='Test')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2, label='X=Y')
plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("Model Performance - Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("ANN Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("ANN Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)

# Ajouter les valeurs de R²
plt.text(300, 50, f'R² (Train): 0.978', fontsize=12, color='blue')
plt.text(300, 40, f'R² (Test): 0.897', fontsize=12, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("ANN Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)

# Ajouter les valeurs de R² dans le graphique
plt.text(0.82, 0.17, f'R² (Train): 0.978', fontsize=12, color='blue', transform=plt.gca().transAxes)
plt.text(0.82, 0.07, f'R² (Test) : 0.897', fontsize=12, color='green', transform=plt.gca().transAxes)

plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
#load the data
dataset=pd.read_excel("Concrete_Data.xls")
dataset.head()
#renaming all featurses
dataset.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']
dataset.head()
x = dataset.drop('strength', axis=1)  # Features (independent variables)
y = dataset['strength']  # Target variable (dependent variable)
# Divisez les données en ensembles de formation et de test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Normalisation des données
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
fixed_params = {
    'hidden_layer_sizes': 132,
    'activation': 'relu',
    'solver': 'lbfgs',
    'max_iter': 5000,
    'alpha': 0.1
}
# Définir le modèle de régression MLP (Multi-layer Perceptron)
model = MLPRegressor(**fixed_params,random_state=42)

# Entraîner le modèle
model.fit(x_train_scaled, y_train)

# Faire des prédictions sur l'ensemble de test
y_pred_test = model.predict(x_test_scaled)

# Calculez les métriques de performance
mae_test = mean_absolute_error(y_test, y_pred_test)
rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)
r2_test = r2_score(y_test, y_pred_test)

# Faites des prédictions sur l'ensemble d'entraînement normalisé
y_pred_train = model.predict(x_train_scaled)

# Calculez les métriques de performance sur l'ensemble d'entraînement
mae_train = mean_absolute_error(y_train, y_pred_train)
rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
r2_train = r2_score(y_train, y_pred_train)

print("Performance sur l'ensemble de test:")
print("Mean Absolute Error (MAE):", mae_test)
print("Root Mean Squared Error (RMSE):", rmse_test)
print("R-squared (R²):", r2_test)

print("\nPerformance sur l'ensemble d'entraînement:")
print("Mean Absolute Error (MAE):", mae_train)
print("Root Mean Squared Error (RMSE):", rmse_train)
print("R-squared (R²):", r2_train)




import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("ANN Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)

# Ajouter les valeurs de R² dans le graphique
plt.text(0.82, 0.17, f'R² (Train): 0.978', fontsize=12, color='blue', transform=plt.gca().transAxes)
plt.text(0.82, 0.07, f'R² (Test) : 0.897', fontsize=12, color='green', transform=plt.gca().transAxes)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Performance sur l'ensemble de test:
# Mean Absolute Error (MAE): 3.2650036287458604
# Root Mean Squared Error (RMSE): 4.9003933881008175
# R-squared (R²): 0.9068078471113867
#
# Performance sur l'ensemble d'entraînement:
# Mean Absolute Error (MAE): 0.7807376914396574
# Root Mean Squared Error (RMSE): 1.4617408889984433
# R-squared (R²): 0.9924786472860471

# %% [markdown]
# **rf**

# %%
from sklearn.ensemble import RandomForestRegressor

# Définir les hyperparamètres pour Random Forest
rf_params = {
    'bootstrap': False,
    'max_depth': 10,
    'max_features': 'log2',
    'n_estimators': 300
}

# Définir le modèle de forêt aléatoire
rf_model = RandomForestRegressor(**rf_params, random_state=42)

# Entraîner le modèle
rf_model.fit(x_train_scaled, y_train)

# Faire des prédictions sur l'ensemble de test
y_pred_test_rf = rf_model.predict(x_test_scaled)

# Calculer les métriques de performance pour l'ensemble de test
mae_test_rf = mean_absolute_error(y_test, y_pred_test_rf)
rmse_test_rf = mean_squared_error(y_test, y_pred_test_rf, squared=False)
r2_test_rf = r2_score(y_test, y_pred_test_rf)

# Faire des prédictions sur l'ensemble d'entraînement
y_pred_train_rf = rf_model.predict(x_train_scaled)

# Calculer les métriques de performance pour l'ensemble d'entraînement
mae_train_rf = mean_absolute_error(y_train, y_pred_train_rf)
rmse_train_rf = mean_squared_error(y_train, y_pred_train_rf, squared=False)
r2_train_rf = r2_score(y_train, y_pred_train_rf)

print("Performance sur l'ensemble de test (Random Forest):")
print("Mean Absolute Error (MAE):", mae_test_rf)
print("Root Mean Squared Error (RMSE):", rmse_test_rf)
print("R-squared (R²):", r2_test_rf)

print("\nPerformance sur l'ensemble d'entraînement (Random Forest):")
print("Mean Absolute Error (MAE):", mae_train_rf)
print("Root Mean Squared Error (RMSE):", rmse_train_rf)
print("R-squared (R²):", r2_train_rf)

import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("ANN Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)

# Ajouter les valeurs de R² dans le graphique
plt.text(0.82, 0.17, f'R² (Train): {r2_train:.3f}', fontsize=12, color='blue', transform=plt.gca().transAxes)
plt.text(0.82, 0.07, f'R² (Test) : {r2_test:.3f}', fontsize=12, color='green', transform=plt.gca().transAxes)

plt.show()
# Out:
# Performance sur l'ensemble de test (Random Forest):
# Mean Absolute Error (MAE): 3.7905045993253186
# Root Mean Squared Error (RMSE): 5.497762245792206
# R-squared (R²): 0.8827023359189833
#
# Performance sur l'ensemble d'entraînement (Random Forest):
# Mean Absolute Error (MAE): 1.127157263708397
# Root Mean Squared Error (RMSE): 1.6826413893400072
# R-squared (R²): 0.9900336003312309

# %%
from sklearn.ensemble import RandomForestRegressor

# Définir les hyperparamètres pour Random Forest
rf_params = {
    'bootstrap': False,
    'max_depth': 15,
    'max_features': 'log2',
    'n_estimators': 54
}

# Définir le modèle de forêt aléatoire
rf_model = RandomForestRegressor(**rf_params, random_state=42)

# Entraîner le modèle
rf_model.fit(x_train_scaled, y_train)

# Faire des prédictions sur l'ensemble de test
y_pred_test_rf = rf_model.predict(x_test_scaled)

# Calculer les métriques de performance pour l'ensemble de test
mae_test_rf = mean_absolute_error(y_test, y_pred_test_rf)
rmse_test_rf = mean_squared_error(y_test, y_pred_test_rf, squared=False)
r2_test_rf = r2_score(y_test, y_pred_test_rf)

# Faire des prédictions sur l'ensemble d'entraînement
y_pred_train_rf = rf_model.predict(x_train_scaled)

# Calculer les métriques de performance pour l'ensemble d'entraînement
mae_train_rf = mean_absolute_error(y_train, y_pred_train_rf)
rmse_train_rf = mean_squared_error(y_train, y_pred_train_rf, squared=False)
r2_train_rf = r2_score(y_train, y_pred_train_rf)

print("Performance sur l'ensemble de test (Random Forest):")
print("Mean Absolute Error (MAE):", mae_test_rf)
print("Root Mean Squared Error (RMSE):", rmse_test_rf)
print("R-squared (R²):", r2_test_rf)

print("\nPerformance sur l'ensemble d'entraînement (Random Forest):")
print("Mean Absolute Error (MAE):", mae_train_rf)
print("Root Mean Squared Error (RMSE):", rmse_train_rf)
print("R-squared (R²):", r2_train_rf)

import matplotlib.pyplot as plt

# Plot pour l'ensemble d'entraînement et de test
plt.figure(figsize=(10, 5))

# Entraînement
plt.scatter(y_train, y_pred_train_rf, color='blue', label='Train')
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='red', linestyle='--', lw=2)

# Test
plt.scatter(y_test, y_pred_test_rf, color='green', label='Test')

plt.xlabel('True Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Predicted Values', fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.title("Random Forest Model Performance - Training and Test Set", fontdict={'fontsize': 14, 'fontweight': 'bold'})
plt.legend()
plt.grid(True)

# Ajouter les valeurs de R² dans le graphique
plt.text(0.82, 0.17, f'R² (Train): 0,936', fontsize=12, color='blue', transform=plt.gca().transAxes)
plt.text(0.82, 0.07, f'R² (Test) : 0,902', fontsize=12, color='green', transform=plt.gca().transAxes)

plt.show()
# Out:
# Performance sur l'ensemble de test (Random Forest):
# Mean Absolute Error (MAE): 3.3816350946566747
# Root Mean Squared Error (RMSE): 5.267237071883041
# R-squared (R²): 0.8923328577325815
#
# Performance sur l'ensemble d'entraînement (Random Forest):
# Mean Absolute Error (MAE): 0.1357186494402956
# Root Mean Squared Error (RMSE): 0.8480846855788551
# R-squared (R²): 0.9974681754533242
