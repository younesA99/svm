# %% [markdown]
# <a href="https://colab.research.google.com/github/younesA99/svm/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Chargement des données
TrainPd = pd.read_excel("Concrete_Data.xls")
TrainPd.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']

# Séparation des caractéristiques et de la cible
X = TrainPd.drop(["strength"], axis=1)
Y = TrainPd["strength"]

# Séparation des ensembles d'entraînement et de test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# Normalisation des données d'entrée
scaler_input = MinMaxScaler()
X_train_transformed = scaler_input.fit_transform(X_train)
X_test_transformed = scaler_input.transform(X_test)

# Normalisation des données de sortie
scaler_output = MinMaxScaler()
Y_train = Y_train.values.reshape(-1, 1)  # Reshape pour s'assurer que c'est une colonne
Y_train_transformed = scaler_output.fit_transform(Y_train)
Y_test = Y_test.values.reshape(-1, 1)  # Reshape pour s'assurer que c'est une colonne
Y_test_transformed = scaler_output.transform(Y_test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ff4d6621f123> in <cell line: 7>()
#       5
#       6 # Chargement des données
# ----> 7 TrainPd = pd.read_excel("Concrete_Data.xls")
#       8 TrainPd.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']
#       9
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

# Charger les données
TrainPd = pd.read_excel("Concrete_Data.xls")
TrainPd.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']

# Séparer les caractéristiques (X) de la cible (Y)
X = TrainPd.drop(["strength"], axis=1)
Y = TrainPd["strength"]

# Division des données en ensembles d'entraînement et de test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# Création du modèle SVR sans normalisation
model_unscaled = SVR(kernel='rbf')

# Entraînement du modèle sans normalisation
model_unscaled.fit(X_train, Y_train)

# Prédictions sur l'ensemble de test sans normalisation
predictions_unscaled = model_unscaled.predict(X_test)
r2_unscaled = r2_score(Y_test, predictions_unscaled)

# Normalisation des données
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# Création du modèle SVR avec normalisation
model_scaled = SVR(kernel='rbf')

# Entraînement du modèle avec normalisation
model_scaled.fit(X_train_normalized, Y_train)

# Prédictions sur l'ensemble de test avec normalisation
predictions_scaled = model_scaled.predict(X_test_normalized)
r2_scaled = r2_score(Y_test, predictions_scaled)

# Affichage des résultats
print(f"R² sans normalisation : {r2_unscaled}")
print(f"R² avec normalisation : {r2_scaled}")
# Out:
# R² sans normalisation : 0.21548520351084677
# R² avec normalisation : 0.5756010720757347

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Charger les données
TrainPd = pd.read_excel("Concrete_Data.xls")
TrainPd.columns = ['cement','blastFurnace','flyAsh','water','superplasticizer','courseAggregate','fineaggregate','age','strength']

# Séparer les caractéristiques (X) de la cible (Y)
X = TrainPd.drop(["strength"], axis=1)
Y = TrainPd["strength"]

# Division des données en ensembles d'entraînement et de test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# Création du modèle SVR sans normalisation
model_unscaled = SVR(kernel='rbf')

# Entraînement du modèle sans normalisation
model_unscaled.fit(X_train, Y_train)

# Création du modèle SVR avec normalisation
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

model_scaled = SVR(kernel='rbf')

# Entraînement du modèle avec normalisation
model_scaled.fit(X_train_normalized, Y_train)

# Prédictions sur l'ensemble de test sans normalisation
predictions_unscaled = model_unscaled.predict(X_test)

# Prédictions sur l'ensemble de test avec normalisation
predictions_scaled = model_scaled.predict(X_test_normalized)

# Visualisation des nuages de points avec la ligne parfaite
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(Y_test, predictions_unscaled)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--', lw=2)  # Ligne parfaite
plt.title('Sans Normalisation')
plt.xlabel('True Values')
plt.ylabel('Predictions')

plt.subplot(1, 2, 2)
plt.scatter(Y_test, predictions_scaled)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--', lw=2)  # Ligne parfaite
plt.title('Avec Normalisation')
plt.xlabel('True Values')
plt.ylabel('Predictions')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score

# Listes pour stocker les performances
r2_scores_unscaled = []
r2_scores_scaled = []
epsilon_values = np.linspace(0.1, 100, 1000)
#epsilon_values = [0.1, 1, 10,100]  # Valeurs d'epsilon à tester

# Modèle sans normalisation
for epsilon in epsilon_values:
    model_unscaled = SVR(kernel='rbf', epsilon=epsilon)
    model_unscaled.fit(X_train, Y_train)
    predictions_unscaled = model_unscaled.predict(X_test)
    r2_unscaled = r2_score(Y_test, predictions_unscaled)
    r2_scores_unscaled.append(r2_unscaled)

# Modèle avec normalisation
for epsilon in epsilon_values:
    model_scaled = SVR(kernel='rbf', epsilon=epsilon)
    model_scaled.fit(X_train_normalized, Y_train)
    predictions_scaled = model_scaled.predict(X_test_normalized)
    r2_scaled = r2_score(Y_test, predictions_scaled)
    r2_scores_scaled.append(r2_scaled)

# Affichage des performances en fonction de l'epsilon
plt.figure(figsize=(8, 5))

plt.plot(epsilon_values, r2_scores_unscaled, label='Sans Normalisation', marker='o')
plt.plot(epsilon_values, r2_scores_scaled, label='Avec Normalisation', marker='o')

plt.xlabel('Valeurs de Epsilon')
plt.ylabel('R²')
plt.title("Performance du modèle SVR en fonction de l'epsilon\n Kernel=rbf ; C=1 ; epsilon_values = [0.1 à 100]")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score

# Listes pour stocker les performances
r2_scores_unscaled = []
r2_scores_scaled = []
epsilon_values = [0.1, 0.01, 0.001]

# Modèle sans normalisation
for epsilon in epsilon_values:
    model_unscaled = SVR(kernel='rbf', epsilon=epsilon)
    model_unscaled.fit(X_train, Y_train)
    predictions_unscaled = model_unscaled.predict(X_test)
    r2_unscaled = r2_score(Y_test, predictions_unscaled)
    r2_scores_unscaled.append(r2_unscaled)

# Modèle avec normalisation
for epsilon in epsilon_values:
    model_scaled = SVR(kernel='rbf', epsilon=epsilon)
    model_scaled.fit(X_train_normalized, Y_train)
    predictions_scaled = model_scaled.predict(X_test_normalized)
    r2_scaled = r2_score(Y_test, predictions_scaled)
    r2_scores_scaled.append(r2_scaled)

# Affichage des performances en fonction de l'epsilon
plt.figure(figsize=(8, 5))

plt.plot(epsilon_values, r2_scores_unscaled, label='Sans Normalisation', marker='o')
plt.plot(epsilon_values, r2_scores_scaled, label='Avec Normalisation', marker='o')

plt.xlabel('Valeurs de Epsilon')
plt.ylabel('R²')
plt.title("Performance du modèle SVR en fonction de l'epsilon\n Kernel=rbf ; C=1 ; epsilon_values = [0.1, 0.01, 0.001]")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Détection des outliers avec la méthode de la plage interquartile (IQR)
outlier_threshold = 2.5  # Choisissez un seuil approprié pour identifier les outliers

for feature in X.columns:
    Q1 = X[feature].quantile(0.25)
    Q3 = X[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - outlier_threshold * IQR
    upper_bound = Q3 + outlier_threshold * IQR

    outliers = X[(X[feature] < lower_bound) | (X[feature] > upper_bound)]
    print(f"Outliers for {feature}: {len(outliers)}")
# Out:
# Outliers for cement: 0
# Outliers for blastFurnace: 0
# Outliers for flyAsh: 0
# Outliers for water: 0
# Outliers for superplasticizer: 0
# Outliers for courseAggregate: 0
# Outliers for fineaggregate: 0
# Outliers for age: 59
